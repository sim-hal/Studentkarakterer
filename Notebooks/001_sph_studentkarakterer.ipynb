# %%
import pandas as pd

# %%
df_mat = pd.read_csv('../Data/student-mat.csv')
df_por = pd.read_csv('../Data/student-por.csv')
df_mat["studytime"]
# Out:
# 0      2
# 1      2
# 2      2
# 3      3
# 4      2
#       ..
# 390    2
# 391    1
# 392    1
# 393    1
# 394    1
# Name: studytime, Length: 395, dtype: int64

# %%
df_mat.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df_por.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
import matplotlib.pyplot as plt

studytime_groups = df_mat.groupby("studytime")

# %%
display(studytime_groups.mean())
# Out:
#                  age      Medu      Fedu  traveltime  failures    famrel  \
# studytime
# 1          16.647619  2.657143  2.438095    1.590476  0.523810  3.876190
# 2          16.702020  2.737374  2.570707    1.414141  0.308081  3.934343
# 3          16.923077  2.907692  2.676923    1.323077  0.230769  4.153846
# 4          16.296296  2.814815  2.111111    1.444444  0.037037  3.777778
#
#            freetime     goout      Dalc      Walc    health  absences  \
# studytime
# 1          3.438095  3.142857  1.761905  2.761905  3.800000  5.761905
# 2          3.217172  3.176768  1.449495  2.267677  3.419192  6.277778
# 3          3.092308  2.892308  1.200000  1.815385  3.723077  4.538462
# 4          2.925926  3.000000  1.296296  1.777778  3.185185  4.148148
#
#                   G1         G2         G3
# studytime
# 1          10.438095  10.276190  10.047619
# 2          10.651515  10.505051  10.171717
# 3          12.046154  11.507692  11.400000
# ...

# %%
studytime_groups.count()
# Out:
#            school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  \
# studytime
# 1             105  105  105      105      105      105   105   105   105
# 2             198  198  198      198      198      198   198   198   198
# 3              65   65   65       65       65       65    65    65    65
# 4              27   27   27       27       27       27    27    27    27
#
#            Fjob  ...  famrel  freetime  goout  Dalc  Walc  health  absences  \
# studytime        ...
# 1           105  ...     105       105    105   105   105     105       105
# 2           198  ...     198       198    198   198   198     198       198
# 3            65  ...      65        65     65    65    65      65        65
# 4            27  ...      27        27     27    27    27      27        27
#
#             G1   G2   G3
# studytime
# 1          105  105  105
# 2          198  198  198
# 3           65   65   65
# 4           27   27   27
#
# [4 rows x 32 columns]

# %%
plt.scatter(df_por["absences"], df_por["G3"])

# %%
df_mat.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df_por.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
import matplotlib.pyplot as plt

studytime_groups = df_mat.groupby("studytime")

# %%
display(studytime_groups.mean())
# Out:
#                  age      Medu      Fedu  traveltime  failures    famrel  \
# studytime
# 1          16.647619  2.657143  2.438095    1.590476  0.523810  3.876190
# 2          16.702020  2.737374  2.570707    1.414141  0.308081  3.934343
# 3          16.923077  2.907692  2.676923    1.323077  0.230769  4.153846
# 4          16.296296  2.814815  2.111111    1.444444  0.037037  3.777778
#
#            freetime     goout      Dalc      Walc    health  absences  \
# studytime
# 1          3.438095  3.142857  1.761905  2.761905  3.800000  5.761905
# 2          3.217172  3.176768  1.449495  2.267677  3.419192  6.277778
# 3          3.092308  2.892308  1.200000  1.815385  3.723077  4.538462
# 4          2.925926  3.000000  1.296296  1.777778  3.185185  4.148148
#
#                   G1         G2         G3
# studytime
# 1          10.438095  10.276190  10.047619
# 2          10.651515  10.505051  10.171717
# 3          12.046154  11.507692  11.400000
# ...

# %%
studytime_groups.count()
# Out:
#            school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  \
# studytime
# 1             105  105  105      105      105      105   105   105   105
# 2             198  198  198      198      198      198   198   198   198
# 3              65   65   65       65       65       65    65    65    65
# 4              27   27   27       27       27       27    27    27    27
#
#            Fjob  ...  famrel  freetime  goout  Dalc  Walc  health  absences  \
# studytime        ...
# 1           105  ...     105       105    105   105   105     105       105
# 2           198  ...     198       198    198   198   198     198       198
# 3            65  ...      65        65     65    65    65      65        65
# 4            27  ...      27        27     27    27    27      27        27
#
#             G1   G2   G3
# studytime
# 1          105  105  105
# 2          198  198  198
# 3           65   65   65
# 4           27   27   27
#
# [4 rows x 32 columns]

# %%
plt.scatter(df_por["absences"], df_por["G3"])
